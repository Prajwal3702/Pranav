# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Dataset and Checking columns names
# + whitespaces
# + irrelevent names

# %%
data = pd.read_csv("Bengaluru_House_Data.csv")
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
data.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %% [markdown]
# # Changing name of columns
# + bath -> Bathrooms
# + price -> Price (Lakhs)

# %%
data.rename(columns={
    'bath' : 'Bathrooms',
    "price" : "Price (Lakhs)"
},inplace=True)
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  Bathrooms  balcony  Price (Lakhs)
# 0          2 BHK  Coomee        1056        2.0      1.0          39.07
# 1      4 Bedroom  Theanmp       2600        5.0      3.0         120.00
# 2          3 BHK      NaN       1440        2.0      3.0          62.00
# 3          3 BHK  Soiewre       1521        3.0      1.0          95.00
# 4          2 BHK      NaN       1200        2.0      1.0          51.00
# ...          ...      ...        ...        ...      ...            ...
# 13315  5 Bedroom  ArsiaEx       3453        4.0      0.0         231.00
# 13316      4 BHK      NaN       3600        5.0      NaN         400.00
# 13317      2 BHK  Mahla T       1141        2.0      1.0          60.00
# 13318      4 BHK  SollyCl       4689        4.0      1.0         488.00
# 13319      1 BHK      NaN        550        1.0      1.0          17.00
#
# [13320 rows x 9 columns]

# %%
data.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'Bathrooms', 'balcony', 'Price (Lakhs)'],
#       dtype='object')

# %% [markdown]
# # Handling missing values

# %%
data.isnull().sum()
# Out:
# area_type           0
# availability        0
# location            1
# size               16
# society          5502
# total_sqft          0
# Bathrooms          73
# balcony           609
# Price (Lakhs)       0
# dtype: int64

# %%
dataset = data.dropna()
dataset.isnull().sum()
# Out:
# area_type        0
# availability     0
# location         0
# size             0
# society          0
# total_sqft       0
# Bathrooms        0
# balcony          0
# Price (Lakhs)    0
# dtype: int64

# %% [markdown]
# # Filter and subset the data based of specific Criteria

# %%
unique, counts,= np.unique(data['area_type'], return_counts=True)
print(f"unique : \n{unique} And Count : \n{counts}")
# Out:
# unique :
# ['Built-up  Area' 'Carpet  Area' 'Plot  Area' 'Super built-up  Area'] And Count :
# [2418   87 2025 8790]

# %%
df = data.drop(['area_type','availability','society'], axis='columns')
df
# Out:
#                        location       size total_sqft  Bathrooms  balcony  \
# 0      Electronic City Phase II      2 BHK       1056        2.0      1.0
# 1              Chikka Tirupathi  4 Bedroom       2600        5.0      3.0
# 2                   Uttarahalli      3 BHK       1440        2.0      3.0
# 3            Lingadheeranahalli      3 BHK       1521        3.0      1.0
# 4                      Kothanur      2 BHK       1200        2.0      1.0
# ...                         ...        ...        ...        ...      ...
# 13315                Whitefield  5 Bedroom       3453        4.0      0.0
# 13316             Richards Town      4 BHK       3600        5.0      NaN
# 13317     Raja Rajeshwari Nagar      2 BHK       1141        2.0      1.0
# 13318           Padmanabhanagar      4 BHK       4689        4.0      1.0
# 13319              Doddathoguru      1 BHK        550        1.0      1.0
#
#        Price (Lakhs)
# 0              39.07
# 1             120.00
# 2              62.00
# 3              95.00
# 4              51.00
# ...              ...
# 13315         231.00
# 13316         400.00
# 13317          60.00
# 13318         488.00
# 13319          17.00
#
# [13320 rows x 6 columns]

# %% [markdown]
# # Handing categorical data

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df['size'] = df['size'].fillna("1 BHK")

# %%
df['BHK'] = df['size'].apply(lambda x: int(x.split(' ')[0]))
df['BHK']
# Out:
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
#         ..
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
# Name: BHK, Length: 13320, dtype: int64

# %% [markdown]
# # Removing column size

# %%
df = df.drop(['size'],axis='columns')
df
# Out:
#                        location total_sqft  Bathrooms  balcony  Price (Lakhs)  \
# 0      Electronic City Phase II       1056        2.0      1.0          39.07
# 1              Chikka Tirupathi       2600        5.0      3.0         120.00
# 2                   Uttarahalli       1440        2.0      3.0          62.00
# 3            Lingadheeranahalli       1521        3.0      1.0          95.00
# 4                      Kothanur       1200        2.0      1.0          51.00
# ...                         ...        ...        ...      ...            ...
# 13315                Whitefield       3453        4.0      0.0         231.00
# 13316             Richards Town       3600        5.0      NaN         400.00
# 13317     Raja Rajeshwari Nagar       1141        2.0      1.0          60.00
# 13318           Padmanabhanagar       4689        4.0      1.0         488.00
# 13319              Doddathoguru        550        1.0      1.0          17.00
#
#        BHK
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
# ...    ...
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
#
# [13320 rows x 6 columns]

# %% [markdown]
# # Aggregate the data to calculate summary statistics or derived metrics such as average sale prices by neighborhood or property type.

# %%
avg_price_by_location = df.groupby('location')['Price (Lakhs)'].mean().reset_index()
print(avg_price_by_location)
# Out:
#                   location  Price (Lakhs)
# 0                   Anekal      16.000000
# 1                Banaswadi      35.000000
# 2              Basavangudi      50.000000
# 3              Bhoganhalli      22.890000
# 4      Devarabeesana Halli     124.833333
# ...                    ...            ...
# 1300             t.c palya     160.000000
# 1301              tc.palya      60.750000
# 1302         vinayakanagar     200.000000
# 1303  white field,kadugodi     275.000000
# 1304            whitefiled      32.730000
#
# [1305 rows x 2 columns]

# %% [markdown]
# # summary statistics

# %%
df.describe()
# Out:
#           Bathrooms       balcony  Price (Lakhs)           BHK
# count  13247.000000  12711.000000   13320.000000  13320.000000
# mean       2.692610      1.584376     112.565627      2.801577
# std        1.341458      0.817263     148.971674      1.295703
# min        1.000000      0.000000       8.000000      1.000000
# 25%        2.000000      1.000000      50.000000      2.000000
# 50%        2.000000      2.000000      72.000000      3.000000
# 75%        3.000000      2.000000     120.000000      3.000000
# max       40.000000      3.000000    3600.000000     43.000000

# %% [markdown]
# # Identify and handle outliers or extreme values in the data that may affect the analysis or modeling process.
# + Price (Lakhs)
# + Bathrooms
# + BHK

# %%
Q1 = df['Price (Lakhs)'].quantile(0.25)
Q3 = df['Price (Lakhs)'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['Price (Lakhs)'] < lower_bound) | (df['Price (Lakhs)'] > upper_bound)]

# Create a boxplot to visualize outliers
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
sns.boxplot(x=df['Price (Lakhs)'], ax=axes[0], color="skyblue")
axes[0].set_title('With Outliers [Price (Lakhs)]')

# Boxplot without outliers
df_clean = df[(df['Price (Lakhs)'] >= lower_bound) & (df['Price (Lakhs)'] <= upper_bound)]
sns.boxplot(x=df_clean['Price (Lakhs)'], color="salmon")
axes[1].set_title('Without Outliers [Price (Lakhs)]')
plt.show()

# %%
Q1 = df['Bathrooms'].quantile(0.25)
Q3 = df['Bathrooms'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['Bathrooms'] < lower_bound) | (df['Bathrooms'] > upper_bound)]

# Create a boxplot to visualize outliers
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
sns.boxplot(x=df['Bathrooms'], ax=axes[0], color="skyblue")
axes[0].set_title('With Outliers [Bathrooms]')

# Boxplot without outliers
df_clean = df[(df['Bathrooms'] >= lower_bound) & (df['Bathrooms'] <= upper_bound)]
sns.boxplot(x=df_clean['Bathrooms'], color="salmon")
axes[1].set_title('Without Outliers [Bathrooms]')
plt.show()

# %%
Q1 = df['BHK'].quantile(0.25)
Q3 = df['BHK'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR 
upper_bound = Q3 + 1.5 * IQR 

outliers = df[(df['BHK'] < lower_bound) | (df['BHK'] > upper_bound)]

fig, axes = plt.subplots(1, 2, figsize=(16, 5))
sns.boxplot(x=df['BHK'], ax=axes[0], color="skyblue")
axes[0].set_title('With Outliers [BHK]')

# Boxplot without outliers
df_clean = df[(df['BHK'] >= lower_bound) & (df['BHK'] <= upper_bound)]
sns.boxplot(x=df_clean['BHK'], ax=axes[1], color="salmon")
axes[1].set_title('Without Outliers [BHK]')
plt.show()
